# %% [markdown]
# ## 3. 安装与认证
#
# > 来源：[Quickstart](https://code.claude.com/docs/en/agent-sdk/quickstart)、[Agent SDK overview](https://code.claude.com/docs/en/agent-sdk/overview)
#
# - 前提：**Python ≥ 3.10**。`pip install` 报 `No matching distribution found for claude-agent-sdk` 就是解释器版本过低（`python3 --version` 查）。
# - `pip install claude-agent-sdk` 后即可运行，无需单独安装 Claude Code。CLI 查找顺序：`cli_path` 显式指定 > 包内捆绑二进制 > PATH 上的 `claude` 命令（捆绑二进制的版本钉死在 SDK 包版本上，升 CLI = 升 SDK 包）。官方 quickstart 的首选安装器是 `uv`（`uv init && uv add claude-agent-sdk`，运行 `uv run agent.py`），pip/conda 同样可用。
#
# 认证走环境变量，五选一（默认走 API key）：
#
# | 提供方 | 环境变量 |
# |---|---|
# | Anthropic API（默认） | `ANTHROPIC_API_KEY` |
# | Amazon Bedrock | `CLAUDE_CODE_USE_BEDROCK=1` + AWS 凭证 |
# | Claude Platform on AWS | `CLAUDE_CODE_USE_ANTHROPIC_AWS=1` + `ANTHROPIC_AWS_WORKSPACE_ID` + AWS 凭证 |
# | Google Vertex AI | `CLAUDE_CODE_USE_VERTEX=1` + GCP 凭证（展开见下） |
# | Microsoft Azure | `CLAUDE_CODE_USE_FOUNDRY=1` + Azure 凭证 |
#
# 以 Vertex AI 为例，完整配置分两部分。第一部分是三个 Claude Code 侧变量：
#
# ```bash
# export CLAUDE_CODE_USE_VERTEX=1                       # 启用 Vertex AI 通道
# export CLOUD_ML_REGION=global                         # 端点位置：global / 多区域 us、eu / 具体区域如 us-east5
# export ANTHROPIC_VERTEX_PROJECT_ID=YOUR-PROJECT-ID    # 用哪个 GCP 项目发请求
# ```
#
# 第二部分是 GCP 凭证本身——不走 Anthropic API key，走 GCP 标准的 Application Default Credentials（ADC），二选一：
#
# - **本机开发**：`gcloud auth application-default login`，浏览器登录后凭证落盘，运行时自动读取，无需设任何变量。
# - **服务器 / CI**：`export GOOGLE_APPLICATION_CREDENTIALS=/path/to/service-account-key.json`，指向 service account 密钥文件。
#
# 前提条件：GCP 项目已启用 Vertex AI API（`gcloud services enable aiplatform.googleapis.com`）、在 Model Garden 里申请开通目标 Claude 模型、账号具有 `roles/aiplatform.user` 角色。
#
# > [!warning] 两个高频坑
# > - **SDK 只从进程环境变量读 key，不会自动加载 `.env` 文件**。key 写在 `.env` 里时要自己先加载（如 `python-dotenv`），否则报 "API key not found"。
# > - 官方明确：未经批准，第三方产品**不允许**用 claude.ai 登录态或其订阅额度来驱动基于 Agent SDK 的产品，请用上面的 API key 方式。

# %%
# %pip install claude-agent-sdk
# Out:
# Requirement already satisfied: claude-agent-sdk in /opt/homebrew/Caskroom/miniconda/base/envs/dev/lib/python3.12/site-packages (0.1.20)
# Requirement already satisfied: anyio>=4.0.0 in /opt/homebrew/Caskroom/miniconda/base/envs/dev/lib/python3.12/site-packages (from claude-agent-sdk) (4.12.1)
# Requirement already satisfied: mcp>=0.1.0 in /opt/homebrew/Caskroom/miniconda/base/envs/dev/lib/python3.12/site-packages (from claude-agent-sdk) (1.25.0)
# Requirement already satisfied: idna>=2.8 in /opt/homebrew/Caskroom/miniconda/base/envs/dev/lib/python3.12/site-packages (from anyio>=4.0.0->claude-agent-sdk) (3.11)
# Requirement already satisfied: typing_extensions>=4.5 in /opt/homebrew/Caskroom/miniconda/base/envs/dev/lib/python3.12/site-packages (from anyio>=4.0.0->claude-agent-sdk) (4.15.0)
# Requirement already satisfied: httpx-sse>=0.4 in /opt/homebrew/Caskroom/miniconda/base/envs/dev/lib/python3.12/site-packages (from mcp>=0.1.0->claude-agent-sdk) (0.4.3)
# Requirement already satisfied: httpx>=0.27.1 in /opt/homebrew/Caskroom/miniconda/base/envs/dev/lib/python3.12/site-packages (from mcp>=0.1.0->claude-agent-sdk) (0.28.1)
# Requirement already satisfied: jsonschema>=4.20.0 in /opt/homebrew/Caskroom/miniconda/base/envs/dev/lib/python3.12/site-packages (from mcp>=0.1.0->claude-agent-sdk) (4.26.0)
# Requirement already satisfied: pydantic-settings>=2.5.2 in /opt/homebrew/Caskroom/miniconda/base/envs/dev/lib/python3.12/site-packages (from mcp>=0.1.0->claude-agent-sdk) (2.12.0)
# Requirement already satisfied: pydantic<3.0.0,>=2.11.0 in /opt/homebrew/Caskroom/miniconda/base/envs/dev/lib/python3.12/site-packages (from mcp>=0.1.0->claude-agent-sdk) (2.12.5)
# Requirement already satisfied: pyjwt>=2.10.1 in /opt/homebrew/Caskroom/miniconda/base/envs/dev/lib/python3.12/site-packages (from pyjwt[crypto]>=2.10.1->mcp>=0.1.0->claude-agent-sdk) (2.10.1)
# Requirement already satisfied: python-multipart>=0.0.9 in /opt/homebrew/Caskroom/miniconda/base/envs/dev/lib/python3.12/site-packages (from mcp>=0.1.0->claude-agent-sdk) (0.0.21)
# Requirement already satisfied: sse-starlette>=1.6.1 in /opt/homebrew/Caskroom/miniconda/base/envs/dev/lib/python3.12/site-packages (from mcp>=0.1.0->claude-agent-sdk) (3.2.0)
# Requirement already satisfied: starlette>=0.27 in /opt/homebrew/Caskroom/miniconda/base/envs/dev/lib/python3.12/site-packages (from mcp>=0.1.0->claude-agent-sdk) (0.51.0)
# Requirement already satisfied: typing-inspection>=0.4.1 in /opt/homebrew/Caskroom/miniconda/base/envs/dev/lib/python3.12/site-packages (from mcp>=0.1.0->claude-agent-sdk) (0.4.2)
# Requirement already satisfied: uvicorn>=0.31.1 in /opt/homebrew/Caskroom/miniconda/base/envs/dev/lib/python3.12/site-packages (from mcp>=0.1.0->claude-agent-sdk) (0.40.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /opt/homebrew/Caskroom/miniconda/base/envs/dev/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.11.0->mcp>=0.1.0->claude-agent-sdk) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in /opt/homebrew/Caskroom/miniconda/base/envs/dev/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.11.0->mcp>=0.1.0->claude-agent-sdk) (2.41.5)
# Requirement already satisfied: certifi in /opt/homebrew/Caskroom/miniconda/base/envs/dev/lib/python3.12/site-packages (from httpx>=0.27.1->mcp>=0.1.0->claude-agent-sdk) (2026.1.4)
# Requirement already satisfied: httpcore==1.* in /opt/homebrew/Caskroom/miniconda/base/envs/dev/lib/python3.12/site-packages (from httpx>=0.27.1->mcp>=0.1.0->claude-agent-sdk) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /opt/homebrew/Caskroom/miniconda/base/envs/dev/lib/python3.12/site-packages (from httpcore==1.*->httpx>=0.27.1->mcp>=0.1.0->claude-agent-sdk) (0.16.0)
# Requirement already satisfied: attrs>=22.2.0 in /opt/homebrew/Caskroom/miniconda/base/envs/dev/lib/python3.12/site-packages (from jsonschema>=4.20.0->mcp>=0.1.0->claude-agent-sdk) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /opt/homebrew/Caskroom/miniconda/base/envs/dev/lib/python3.12/site-packages (from jsonschema>=4.20.0->mcp>=0.1.0->claude-agent-sdk) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /opt/homebrew/Caskroom/miniconda/base/envs/dev/lib/python3.12/site-packages (from jsonschema>=4.20.0->mcp>=0.1.0->claude-agent-sdk) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in /opt/homebrew/Caskroom/miniconda/base/envs/dev/lib/python3.12/site-packages (from jsonschema>=4.20.0->mcp>=0.1.0->claude-agent-sdk) (0.30.0)
# Requirement already satisfied: python-dotenv>=0.21.0 in /opt/homebrew/Caskroom/miniconda/base/envs/dev/lib/python3.12/site-packages (from pydantic-settings>=2.5.2->mcp>=0.1.0->claude-agent-sdk) (1.2.1)
# Requirement already satisfied: cryptography>=3.4.0 in /opt/homebrew/Caskroom/miniconda/base/envs/dev/lib/python3.12/site-packages (from pyjwt[crypto]>=2.10.1->mcp>=0.1.0->claude-agent-sdk) (46.0.3)
# Requirement already satisfied: cffi>=2.0.0 in /opt/homebrew/Caskroom/miniconda/base/envs/dev/lib/python3.12/site-packages (from cryptography>=3.4.0->pyjwt[crypto]>=2.10.1->mcp>=0.1.0->claude-agent-sdk) (2.0.0)
# Requirement already satisfied: pycparser in /opt/homebrew/Caskroom/miniconda/base/envs/dev/lib/python3.12/site-packages (from cffi>=2.0.0->cryptography>=3.4.0->pyjwt[crypto]>=2.10.1->mcp>=0.1.0->claude-agent-sdk) (2.23)
# Requirement already satisfied: click>=7.0 in /opt/homebrew/Caskroom/miniconda/base/envs/dev/lib/python3.12/site-packages (from uvicorn>=0.31.1->mcp>=0.1.0->claude-agent-sdk) (8.3.1)
# Note: you may need to restart the kernel to use updated packages.
